# %% [markdown]
# ## Clustering the spotify dataframe

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %% [markdown]
# #### Loading the dataset

# %%
spotify_maris_df = pd.read_csv('spotify_df.csv')

# %%
spotify_maris_df
# Out:
#       Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0              0         0.522   0.817    0    -6.170     1       0.0512
# 1              1         0.692   0.651    9    -8.267     1       0.0324
# 2              2         0.682   0.605    8   -10.771     1       0.0403
# 3              3         0.793   0.601    4    -8.179     1       0.0317
# 4              4         0.873   0.651    1    -4.179     1       0.0374
# ...          ...           ...     ...  ...       ...   ...          ...
# 4326         986         0.724   0.804   11    -4.614     0       0.0448
# 4327         987         0.621   0.310    9   -10.164     0       0.0283
# 4328         988         0.668   0.778    7    -4.302     0       0.0506
# 4329         989         0.814   0.482    9   -10.493     1       0.0588
# 4330         990         0.489   0.701    7   -10.530     1       0.0348
#
#       acousticness  instrumentalness  liveness  ...    tempo            type  \
# ...

# %%
spotify_cristina_df = pd.read_csv('spotify1__df.csv')

# %%
spotify_cristina_df
# Out:
#       Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0              0         0.918   0.609   10    -5.640     0       0.0791
# 1              1         0.899   0.713    6    -2.752     0       0.3660
# 2              2         0.957   0.737    2    -4.880     1       0.1150
# 3              3         0.664   0.758    2    -6.583     0       0.2100
# 4              4         0.768   0.864   11    -6.145     1       0.0324
# ...          ...           ...     ...  ...       ...   ...          ...
# 1768         135         0.964   0.540    5    -8.462     0       0.0763
# 1769         136         0.671   0.636    6    -8.117     0       0.1030
# 1770         137         0.573   0.856    9    -4.807     1       0.3710
# 1771         138         0.514   0.661    0   -11.447     1       0.0415
# 1772         139         0.693   0.913    0    -3.035     1       0.0298
#
#       acousticness  instrumentalness  liveness  ...    tempo            type  \
# ...

# %%
spotify_cristina_2_df = pd.read_csv('spotify2__df.csv')

# %%
spotify_cristina_2_df
# Out:
#       Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0              0         0.695  0.5400    4    -5.692     1       0.0493
# 1              1         0.591  0.7640    1    -5.484     1       0.0483
# 2              2         0.796  0.7980    1    -6.312     1       0.0317
# 3              3         0.761  0.5250   11    -6.900     1       0.0944
# 4              4         0.788  0.8590    2    -2.724     1       0.0856
# ...          ...           ...     ...  ...       ...   ...          ...
# 1273         442         0.628  0.7370    7    -4.437     1       0.0410
# 1274         443         0.784  0.5390    8    -8.148     0       0.0628
# 1275         444         0.410  0.0485    0   -13.918     1       0.0380
# 1276         445         0.854  0.6740   11    -4.896     1       0.0705
# 1277         446         0.908  0.6690    7    -2.827     1       0.0738
#
#       acousticness  instrumentalness  liveness  ...    tempo            type  \
# ...

# %%
# Putting together the final dataframe.

spotify_final_df = pd.concat([spotify_maris_df,spotify_cristina_df,spotify_cristina_2_df], axis = 0).reset_index()

# %%
# Deleting unnecessary columns.

spotify_final_df.drop(columns = ["index", "Unnamed: 0"], inplace = True)

# %%
spotify_final_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.522  0.8170    0    -6.170     1       0.0512       0.32900
# 1            0.692  0.6510    9    -8.267     1       0.0324       0.29200
# 2            0.682  0.6050    8   -10.771     1       0.0403       0.18500
# 3            0.793  0.6010    4    -8.179     1       0.0317       0.03120
# 4            0.873  0.6510    1    -4.179     1       0.0374       0.02510
# ...            ...     ...  ...       ...   ...          ...           ...
# 7377         0.628  0.7370    7    -4.437     1       0.0410       0.06250
# 7378         0.784  0.5390    8    -8.148     0       0.0628       0.69000
# 7379         0.410  0.0485    0   -13.918     1       0.0380       0.94700
# 7380         0.854  0.6740   11    -4.896     1       0.0705       0.02040
# 7381         0.908  0.6690    7    -2.827     1       0.0738       0.00286
#
# ...

# %%
spotify_final_df.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   7382.000000  7382.000000  7382.000000  7382.000000  7382.000000
# mean       0.647453     0.588702     5.109591    -8.616261     0.614061
# std        0.153301     0.223335     3.614284     5.186738     0.486849
# min        0.000000     0.002120     0.000000   -43.738000     0.000000
# 25%        0.561000     0.444250     2.000000   -10.002000     0.000000
# 50%        0.664000     0.616000     5.000000    -7.005500     1.000000
# 75%        0.753000     0.761000     8.000000    -5.268500     1.000000
# max        0.980000     1.000000    11.000000     0.175000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  7382.000000   7382.000000       7382.000000  7382.000000  7382.000000
# mean      0.090909      0.295054          0.113230     0.170873     0.527714
# std       0.094105      0.302832          0.272465     0.136327     0.238229
# ...

# %% [markdown]
#  #### Using StandardScaler to standardize the dataframe.

# %%
# I will get only numerical columns for that.

spotify_final_df_num = spotify_final_df._get_numeric_data()
spotify_final_df_num
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.522  0.8170    0    -6.170     1       0.0512       0.32900
# 1            0.692  0.6510    9    -8.267     1       0.0324       0.29200
# 2            0.682  0.6050    8   -10.771     1       0.0403       0.18500
# 3            0.793  0.6010    4    -8.179     1       0.0317       0.03120
# 4            0.873  0.6510    1    -4.179     1       0.0374       0.02510
# ...            ...     ...  ...       ...   ...          ...           ...
# 7377         0.628  0.7370    7    -4.437     1       0.0410       0.06250
# 7378         0.784  0.5390    8    -8.148     0       0.0628       0.69000
# 7379         0.410  0.0485    0   -13.918     1       0.0380       0.94700
# 7380         0.854  0.6740   11    -4.896     1       0.0705       0.02040
# 7381         0.908  0.6690    7    -2.827     1       0.0738       0.00286
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
# Dropping unnecessary columns.

spotify_final_df_num.drop(columns = ["key", "mode", "time_signature"], inplace = True)

# %%
spotify_final_df_num
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.522  0.8170    -6.170       0.0512       0.32900
# 1            0.692  0.6510    -8.267       0.0324       0.29200
# 2            0.682  0.6050   -10.771       0.0403       0.18500
# 3            0.793  0.6010    -8.179       0.0317       0.03120
# 4            0.873  0.6510    -4.179       0.0374       0.02510
# ...            ...     ...       ...          ...           ...
# 7377         0.628  0.7370    -4.437       0.0410       0.06250
# 7378         0.784  0.5390    -8.148       0.0628       0.69000
# 7379         0.410  0.0485   -13.918       0.0380       0.94700
# 7380         0.854  0.6740    -4.896       0.0705       0.02040
# 7381         0.908  0.6690    -2.827       0.0738       0.00286
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000002    0.0807    0.562  151.106       204693
# 1             0.002410    0.1050    0.706   97.923       254560
# ...

# %%
# Scaling using StandardScaler.

scaler = StandardScaler()
scaler.fit(spotify_final_df_num)
spotify_final_df_num_scaled = scaler.transform(spotify_final_df_num)
spotify_final_df_num_scaled_df = pd.DataFrame(spotify_final_df_num_scaled, columns = spotify_final_df_num.columns)

display(spotify_final_df_num_scaled_df)
# Out:
#       danceability    energy  loudness  speechiness  acousticness  \
# 0        -0.818404  1.022293  0.471670    -0.421990      0.112103
# 1         0.290603  0.278965  0.067342    -0.621782     -0.010085
# 2         0.225368  0.072982 -0.415460    -0.537827     -0.363440
# 3         0.949484  0.055070  0.084309    -0.629221     -0.871346
# 4         1.471370  0.278965  0.855559    -0.568646     -0.891491
# ...            ...       ...       ...          ...           ...
# 7377     -0.126905  0.664062  0.805814    -0.530388     -0.767982
# 7378      0.890772 -0.222558  0.090287    -0.298715      1.304262
# 7379     -1.549045 -2.418959 -1.022241    -0.562269      2.152973
# 7380      1.347422  0.381956  0.717313    -0.216886     -0.907012
# 7381      1.699695  0.359566  1.116242    -0.181816     -0.964935
#
#       instrumentalness  liveness   valence     tempo  duration_ms
# 0            -0.415597 -0.661491  0.143928  1.109252    -0.116854
# ...

# %%
spotify_final_df_num_scaled_df.columns
# Out:
# Index(['danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms'],
#       dtype='object')

# %% [markdown]
# #### Clustering

# %%
# Making the clusters.

kmeans = KMeans(n_clusters=8, random_state=1234)
kmeans.fit(spotify_final_df_num_scaled_df)
# Out:
# KMeans(random_state=1234)

# %%
kmeans.labels_
# Out:
# array([7, 3, 3, ..., 1, 3, 3], dtype=int32)

# %%
# How many songs in every cluster.

clusters = kmeans.predict(spotify_final_df_num_scaled_df)

pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     780
# 1     896
# 2    1627
# 3    1923
# 4     439
# 5     190
# 6     705
# 7     822
# dtype: int64

# %%
# Making a copy of the dataframe to add a new column. I made a copy, because it otherwise changed also the standardized df.

features_df = spotify_final_df_num_scaled_df.copy()
features_df
# Out:
#       danceability    energy  loudness  speechiness  acousticness  \
# 0        -0.818404  1.022293  0.471670    -0.421990      0.112103
# 1         0.290603  0.278965  0.067342    -0.621782     -0.010085
# 2         0.225368  0.072982 -0.415460    -0.537827     -0.363440
# 3         0.949484  0.055070  0.084309    -0.629221     -0.871346
# 4         1.471370  0.278965  0.855559    -0.568646     -0.891491
# ...            ...       ...       ...          ...           ...
# 7377     -0.126905  0.664062  0.805814    -0.530388     -0.767982
# 7378      0.890772 -0.222558  0.090287    -0.298715      1.304262
# 7379     -1.549045 -2.418959 -1.022241    -0.562269      2.152973
# 7380      1.347422  0.381956  0.717313    -0.216886     -0.907012
# 7381      1.699695  0.359566  1.116242    -0.181816     -0.964935
#
#       instrumentalness  liveness   valence     tempo  duration_ms
# 0            -0.415597 -0.661491  0.143928  1.109252    -0.116854
# ...

# %%
# Adding a new column with corresponding clusters.

features_df["cluster"] = clusters
features_df
# Out:
#       danceability    energy  loudness  speechiness  acousticness  \
# 0        -0.818404  1.022293  0.471670    -0.421990      0.112103
# 1         0.290603  0.278965  0.067342    -0.621782     -0.010085
# 2         0.225368  0.072982 -0.415460    -0.537827     -0.363440
# 3         0.949484  0.055070  0.084309    -0.629221     -0.871346
# 4         1.471370  0.278965  0.855559    -0.568646     -0.891491
# ...            ...       ...       ...          ...           ...
# 7377     -0.126905  0.664062  0.805814    -0.530388     -0.767982
# 7378      0.890772 -0.222558  0.090287    -0.298715      1.304262
# 7379     -1.549045 -2.418959 -1.022241    -0.562269      2.152973
# 7380      1.347422  0.381956  0.717313    -0.216886     -0.907012
# 7381      1.699695  0.359566  1.116242    -0.181816     -0.964935
#
#       instrumentalness  liveness   valence     tempo  duration_ms  cluster
# 0            -0.415597 -0.661491  0.143928  1.109252    -0.116854        7
# ...

# %%
# Checking the inertia.

kmeans.inertia_
# Out:
# 33542.9639342589

# %%
# Figuring out how many clusters would be good. Using elbow method.

K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(spotify_final_df_num_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
# Figuring out how many clusters would be good. Using silhouette method.

K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(spotify_final_df_num_scaled_df)
    
    
    silhouette.append(silhouette_score(spotify_final_df_num_scaled_df, kmeans.predict(spotify_final_df_num_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
# Saving my count of clusters. Decided the amount based on silhouette plot.

kmeans = KMeans(n_clusters=8,
                    random_state=1234)
kmeans.fit(spotify_final_df_num_scaled_df)
# Out:
# KMeans(random_state=1234)

# %%
# Saving my model to my computer.

import pickle

with open("scaler.pickle", "wb") as f:
    pickle.dump(scaler,f)

with open("kmeans_9.pickle", "wb") as f:
    pickle.dump(kmeans,f)

# %%
# Joining the audio features dataframe to song information dataframe.

spotify_songs = pd.concat([spotify_final_df, features_df], axis = 1)

# %%
spotify_songs
# Out:
#       danceability  energy  key loudness  mode speechiness acousticness  \
# 0            0.522  0.8170    0   -6.170     1      0.0512      0.32900
# 1            0.692  0.6510    9   -8.267     1      0.0324      0.29200
# 2            0.682  0.6050    8  -10.771     1      0.0403      0.18500
# 3            0.793  0.6010    4   -8.179     1      0.0317      0.03120
# 4            0.873  0.6510    1   -4.179     1      0.0374      0.02510
# ...            ...     ...  ...      ...   ...         ...          ...
# 7377         0.628  0.7370    7   -4.437     1      0.0410      0.06250
# 7378         0.784  0.5390    8   -8.148     0      0.0628      0.69000
# 7379         0.410  0.0485    0  -13.918     1      0.0380      0.94700
# 7380         0.854  0.6740   11   -4.896     1      0.0705      0.02040
# 7381         0.908  0.6690    7   -2.827     1      0.0738      0.00286
#
#      instrumentalness liveness  valence  ...    energy  loudness speechiness  \
# ...

# %%
# Saving the dataframe as csv.

spotify_songs.to_csv("spotify_songs.csv")
